# %%
import matplotlib.pyplot as plt
from vcf_compare.comparison import (
    Venn2VariantComparison, 
    Venn4VariantComparison, 
    EulerVariantComparison,
    Position
)

old_vcf_path = "HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.1_highconf_phased.vcf.gz"
new_vcf_path = "HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz"

# %%
ax = Venn2VariantComparison(
    old_vcf_path,
    new_vcf_path
).plot()
plt.show()
# Out:
# Loading old: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.1_highconf_phased.vcf.gz
# Loading new: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz
# Comparing sets...
# Plotting...

# %%
ax_pass = Venn2VariantComparison(
    old_vcf_path, 
    new_vcf_path,
    pass_only=True
).plot()
plt.show()
# Out:
# Loading old: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.1_highconf_phased.vcf.gz
# Loading new: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz
# Comparing sets...
# Plotting...

# %%
ax = Venn4VariantComparison(
    old_vcf_path,
    new_vcf_path
).plot()
plt.show()
# Out:
# Loading old: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.1_highconf_phased.vcf.gz
# Loading new: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz
# Comparing sets...
# Plotting...

# %%
ax = EulerVariantComparison(
    old_vcf_path,
    new_vcf_path
).plot()
plt.show()
# Out:
# Loading old: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.1_highconf_phased.vcf.gz
# Loading new: HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz
# Comparing sets...
# Plotting...

# %%
ax = Position(("HG001_GRCh38_GIAB 3.3.1", old_vcf_path), ("HG001_GRCh38_GIAB 3.3.2", new_vcf_path)).plot()
plt.show()
# Out:
# /nfs/users/nfs_t/td14/git/vcf-compare/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
